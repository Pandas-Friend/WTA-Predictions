# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import dependencies
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sqlalchemy import create_engine
import psycopg2 
import psycopg2.extras
import io

# %%
# Create a dataframe
df = pd.read_csv('https://raw.githubusercontent.com/JeffSackmann/tennis_wta/master/wta_matches_2021.csv')
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2021-2028    Abu Dhabi    Hard         64             P      20210106
# 1  2021-2028    Abu Dhabi    Hard         64             P      20210106
# 2  2021-2028    Abu Dhabi    Hard         64             P      20210106
# 3  2021-2028    Abu Dhabi    Hard         64             P      20210106
# 4  2021-2028    Abu Dhabi    Hard         64             P      20210106
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     214544          NaN          NaN  ...    31.0     18.0
# 1        299     206368          NaN          NaN  ...    46.0     28.0
# 2        298     206289          NaN          NaN  ...    52.0     26.0
# 3        297     214544          NaN          NaN  ...    44.0     30.0
# 4        296     216146          NaN          NaN  ...    56.0     25.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# ...

# %%
from config import db_password

# %%
# Create the database engine
engine = create_engine('postgresql://postgres:Danza1987!@localhost:5432/WTA')
df.to_sql('matches', con=engine, if_exists='append',index=False)

# %% [markdown]
# # Example python program to read data from a PostgreSQL table and load into a pandas DataFrame

# %%
# Connect to PostgreSQL server
dbConnection = engine.connect()

# %%
# Read data from PostgreSQL database table and load into a DataFrame instance
dataFrame = pd.read_sql("select * from \"matches\"", dbConnection)

# %%
# Print the DataFrame
dataFrame.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2021-2028    Abu Dhabi    Hard         64             P      20210106
# 1  2021-2028    Abu Dhabi    Hard         64             P      20210106
# 2  2021-2028    Abu Dhabi    Hard         64             P      20210106
# 3  2021-2028    Abu Dhabi    Hard         64             P      20210106
# 4  2021-2028    Abu Dhabi    Hard         64             P      20210106
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     214544          NaN         None  ...    31.0     18.0
# 1        299     206368          NaN         None  ...    46.0     28.0
# 2        298     206289          NaN         None  ...    52.0     26.0
# 3        297     214544          NaN         None  ...    44.0     30.0
# 4        296     216146          NaN         None  ...    56.0     25.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# ...

# %%
# Close the database connection
dbConnection.close();
