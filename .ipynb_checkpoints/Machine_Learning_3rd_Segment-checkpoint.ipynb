# %% [markdown]
# ## Example of python program converting a raw CSV file to a DataFrame and then exporting to a PostgresSQL table

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Import dependencies
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sqlalchemy import create_engine
import psycopg2 
import psycopg2.extras
import io
import getpass
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from imblearn.ensemble import BalancedRandomForestClassifier

# %%
try:
    p = getpass.getpass()
except Exception as error:
    print('ERROR', error)
# Out:
# ········

# %%
engine = create_engine('postgresql://postgres:' + p + '@localhost:5432/WTA')

# %% [markdown]
# # Example python program to read data from a PostgreSQL table and load into a pandas DataFrame

# %%
# Connect to PostgreSQL server
dbConnection = engine.connect()

# %%
# Read data from PostgreSQL database table and load into a DataFrame instance
dataFrame = pd.read_sql("select * from \"matches\"", dbConnection)

# %%
# Print the DataFrame
dataFrame.head()
# Out:
#    index  tourney_date               tourney_name tourney_level surface  \
# 0      0      20100206  Fed Cup WG R1: UKR vs ITA             D    Hard
# 1      1      20100206  Fed Cup WG R1: UKR vs ITA             D    Hard
# 2      2      20100206  Fed Cup WG R1: UKR vs ITA             D    Hard
# 3      3      20100206  Fed Cup WG R1: UKR vs ITA             D    Hard
# 4      4      20100206  Fed Cup WG R1: CZE vs GER             D    Hard
#
#   rounds  best_of  winner_id           winner_name  winner_rank  loser_id  \
# 0     RR        3     201416      Alona Bondarenko         26.0    201212
# 1     RR        3     201355       Flavia Pennetta         12.0    201435
# 2     RR        3     201355       Flavia Pennetta         12.0    201416
# 3     RR        3     201212   Francesca Schiavone         18.0    201435
# 4     RR        3     201394  Anna Lena Groenefeld         66.0    201425
#
#             loser_name  loser_rank
# 0  Francesca Schiavone        18.0
# 1  Kateryna Bondarenko        33.0
# 2     Alona Bondarenko        26.0
# 3  Kateryna Bondarenko        33.0
# 4       Lucie Safarova        46.0

# %%
# Close the database connection
dbConnection.close();

# %% [markdown]
# ## Example of pre-processing data before plugging it on a Machine Learning model

# %%
dataFrame.shape
# Out:
# (22309, 13)

# %%
dataFrame.dtypes
# Out:
# index              int64
# tourney_date       int64
# tourney_name      object
# tourney_level     object
# surface           object
# rounds            object
# best_of            int64
# winner_id          int64
# winner_name       object
# winner_rank      float64
# loser_id           int64
# loser_name        object
# loser_rank       float64
# dtype: object

# %%
# Converting tourney_date to datetime format
dataFrame['tourney_date'] = pd.to_datetime(dataFrame['tourney_date'], format='%Y%m%d') 
# Choosing features
cols_to_keep = ['tourney_date','tourney_name','surface', 'rounds', 'winner_rank','loser_rank']
# Dropping NaN
dataFrame = dataFrame[cols_to_keep].dropna()
# Dropping errors in the dataset 
dataFrame = dataFrame[(dataFrame['loser_rank'] != 'NR') & (dataFrame['winner_rank'] != 'NR')]
dataFrame.head()
# Out:
#   tourney_date               tourney_name surface rounds  winner_rank  \
# 0   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR         26.0
# 1   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR         12.0
# 2   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR         12.0
# 3   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR         18.0
# 4   2010-02-06  Fed Cup WG R1: CZE vs GER    Hard     RR         66.0
#
#    loser_rank
# 0        18.0
# 1        33.0
# 2        26.0
# 3        33.0
# 4        46.0

# %%
dataFrame.shape
# Out:
# (22306, 6)

# %%
dataFrame.dtypes
# Out:
# tourney_date    datetime64[ns]
# tourney_name            object
# surface                 object
# rounds                  object
# winner_rank            float64
# loser_rank             float64
# dtype: object

# %%
# Transform strings into numerical values
dataFrame[['winner_rank','loser_rank']] = dataFrame[['winner_rank','loser_rank']].astype(int)
dataFrame.head()
# Out:
#   tourney_date               tourney_name surface rounds  winner_rank  \
# 0   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR           26
# 1   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR           12
# 2   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR           12
# 3   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR           18
# 4   2010-02-06  Fed Cup WG R1: CZE vs GER    Hard     RR           66
#
#    loser_rank
# 0          18
# 1          33
# 2          26
# 3          33
# 4          46

# %%
dataFrame.dtypes
# Out:
# tourney_date    datetime64[ns]
# tourney_name            object
# surface                 object
# rounds                  object
# winner_rank              int32
# loser_rank               int32
# dtype: object

# %%
# Create an extra columns for the variable win described above using an auxiliary function win(x)
def win(x):
    if x > 0:
        return 0
    elif x <= 0:
        return 1  
    
dataFrame['win'] = (dataFrame['winner_rank'] - dataFrame['loser_rank']).apply(win)
dataFrame.head()
# Out:
#   tourney_date               tourney_name surface rounds  winner_rank  \
# 0   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR           26
# 1   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR           12
# 2   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR           12
# 3   2010-02-06  Fed Cup WG R1: UKR vs ITA    Hard     RR           18
# 4   2010-02-06  Fed Cup WG R1: CZE vs GER    Hard     RR           66
#
#    loser_rank  win
# 0          18    0
# 1          33    1
# 2          26    1
# 3          33    1
# 4          46    0

# %%
# Check win frequency

print(dataFrame['win'].sum(axis=0))
print(len(dataFrame.index))
dataFrame['win'].sum(axis=0)/float(len(dataFrame.index))
# Out:
# 14196
# 22306
# 0.6364206939836815

# %%
# To correct our uneven win frequency we use Stratified sampling 
y_0 = dataFrame[dataFrame.win == 0] 
y_1 = dataFrame[dataFrame.win == 1] 
n = min([len(y_0), len(y_1)]) 
y_0 = y_0.sample(n = n, random_state = 0) 
y_1 = y_1.sample(n = n, random_state = 0)
df_strat = pd.concat([y_0, y_1]) 
X_strat = df_strat[['tourney_date','tourney_name','surface', 'rounds', 'winner_rank','loser_rank']]
y_strat = df_strat.win

# %%
X_strat.head()
# Out:
#       tourney_date tourney_name surface rounds  winner_rank  loser_rank
# 12962   2016-05-16   Strasbourg    Clay    R16           66          44
# 5225    2012-05-07       Madrid    Clay    R32           41          19
# 14741   2016-10-17       Moscow    Hard    R32           47          44
# 15027   2016-08-08     Olympics    Hard    R16           34           4
# 696     2010-07-19     Portoroz    Hard    R16          129           2

# %%
y_strat.head()
# Out:
# 12962    0
# 5225     0
# 14741    0
# 15027    0
# 696      0
# Name: win, dtype: int64

# %%
X_strat_1=X_strat.copy()
X_strat_1['win']=y_strat
X_strat_1.head()
# Out:
#       tourney_date tourney_name surface rounds  winner_rank  loser_rank  win
# 12962   2016-05-16   Strasbourg    Clay    R16           66          44    0
# 5225    2012-05-07       Madrid    Clay    R32           41          19    0
# 14741   2016-10-17       Moscow    Hard    R32           47          44    0
# 15027   2016-08-08     Olympics    Hard    R16           34           4    0
# 696     2010-07-19     Portoroz    Hard    R16          129           2    0

# %%
# define the variables P1 and P2
df0 = X_strat_1.copy()
df0["P1"] = df0[["winner_rank", "loser_rank"]].max(axis=1)
df0["P2"] = df0[["winner_rank", "loser_rank"]].min(axis=1)
df0.head()
# Out:
#       tourney_date tourney_name surface rounds  winner_rank  loser_rank  win  \
# 12962   2016-05-16   Strasbourg    Clay    R16           66          44    0
# 5225    2012-05-07       Madrid    Clay    R32           41          19    0
# 14741   2016-10-17       Moscow    Hard    R32           47          44    0
# 15027   2016-08-08     Olympics    Hard    R16           34           4    0
# 696     2010-07-19     Portoroz    Hard    R16          129           2    0
#
#         P1  P2
# 12962   66  44
# 5225    41  19
# 14741   47  44
# 15027   34   4
# 696    129   2

# %% [markdown]
# ### Exploratory Analysis for the DataFrame

# %%
print(dataFrame['surface'].unique())
# Out:
# ['Hard' 'Clay' 'Carpet' 'Grass']

# %%
# Look at percentage of wins for each surface. 
win_by_Surface = pd.crosstab(dataFrame.win, dataFrame.surface).apply( lambda x: x/x.sum(), axis = 0 )
win_by_Surface
# Out:
# surface    Carpet      Clay     Grass      Hard
# win
# 0        0.326087  0.375833  0.365225  0.358697
# 1        0.673913  0.624167  0.634775  0.641303

# %%
print(dataFrame['rounds'].unique())
# Out:
# ['RR' 'QF' 'SF' 'F' 'R32' 'R16' 'R64' 'R128' 'BR']

# %%
# Look at percentage of wins for each round.
win_by_round = pd.crosstab(dataFrame.win, dataFrame['rounds']).apply( lambda x: x/x.sum(), axis = 0 )
win_by_round
# Out:
# rounds   BR         F        QF      R128       R16       R32       R64  \
# win
# 0       1.0  0.397924  0.377127  0.337172  0.377783  0.363873  0.354203
# 1       0.0  0.602076  0.622873  0.662828  0.622217  0.636127  0.645797
#
# rounds        RR        SF
# win
# 0       0.348451  0.378947
# 1       0.651549  0.621053

# %% [markdown]
# #### Dummy variables

# %%
df = dataFrame[(dataFrame['rounds'] != 'BR') & (dataFrame['rounds'] != 'RR') ]
df.head()
# Out:
#    tourney_date             tourney_name surface rounds  winner_rank  \
# 86   2010-11-01  Tournament of Champions    Hard     QF           53
# 87   2010-11-01  Tournament of Champions    Hard     QF           24
# 88   2010-11-01  Tournament of Champions    Hard     QF           31
# 89   2010-11-01  Tournament of Champions    Hard     QF           27
# 90   2010-11-01  Tournament of Champions    Hard     SF           24
#
#     loser_rank  win
# 86          11    0
# 87          20    0
# 88          22    0
# 89          18    0
# 90          53    1

# %%
df1 = df.copy()
dummy_ranks = pd.get_dummies(df1['rounds'])
dummy_ranks.head()
# Out:
#     F  QF  R128  R16  R32  R64  SF
# 86  0   1     0    0    0    0   0
# 87  0   1     0    0    0    0   0
# 88  0   1     0    0    0    0   0
# 89  0   1     0    0    0    0   0
# 90  0   0     0    0    0    0   1

# %%
# To keep the dataframe cleaner, we transform the Round entries into numbers. We then transform rounds into dummy variables
def round_convert(x):
    if x == 'R128':
        return 1
    elif x == 'R64':
        return 2
    elif x == 'R32':
        return 3
    elif x == 'R16':
        return 4
    elif x == 'QF':
        return 5
    elif x == 'SF':
        return 6
    elif x == 'F':
        return 7
    
df1['rounds'] = df1['rounds'].apply(round_convert)
df1['rounds'].head()
# Out:
# 86    5
# 87    5
# 88    5
# 89    5
# 90    6
# Name: rounds, dtype: int64

# %%
df_rounds = df1.join(dummy_ranks)
df_rounds.head()
# Out:
#    tourney_date             tourney_name surface  rounds  winner_rank  \
# 86   2010-11-01  Tournament of Champions    Hard       5           53
# 87   2010-11-01  Tournament of Champions    Hard       5           24
# 88   2010-11-01  Tournament of Champions    Hard       5           31
# 89   2010-11-01  Tournament of Champions    Hard       5           27
# 90   2010-11-01  Tournament of Champions    Hard       6           24
#
#     loser_rank  win  surface_Carpet  surface_Clay  surface_Grass  surface_Hard
# 86          11    0               0             0              0             1
# 87          20    0               0             0              0             1
# 88          22    0               0             0              0             1
# 89          18    0               0             0              0             1
# 90          53    1               0             0              0             1

# %%
dummy_ranks = pd.get_dummies(df1['surface'], prefix='surface')
dummy_ranks.sample(10)
# Out:
#        surface_Carpet  surface_Clay  surface_Grass  surface_Hard
# 6898                0             0              0             1
# 4387                0             0              0             1
# 17885               0             1              0             0
# 10437               0             1              0             0
# 1156                0             0              0             1
# 10041               0             0              0             1
# 4559                0             1              0             0
# 1150                0             0              0             1
# 13740               0             0              0             1
# 3138                0             0              0             1

# %%
df_2 = df_rounds.join(dummy_ranks)
df_2.drop("surface",axis = 1,inplace=True)
df_2[['surface_Grass','surface_Hard']] = df_2[['surface_Grass','surface_Hard']].astype('int_')
df_2.drop("rounds",axis = 1,inplace=True)
df_2.head()
# Out:
#    tourney_date             tourney_name  winner_rank  loser_rank  win  F  QF  \
# 86   2010-11-01  Tournament of Champions           53          11    0  0   1
# 87   2010-11-01  Tournament of Champions           24          20    0  0   1
# 88   2010-11-01  Tournament of Champions           31          22    0  0   1
# 89   2010-11-01  Tournament of Champions           27          18    0  0   1
# 90   2010-11-01  Tournament of Champions           24          53    1  0   0
#
#     R128  R16  R32  R64  SF  surface_Carpet  surface_Clay  surface_Grass  \
# 86     0    0    0    0   0               0             0              0
# 87     0    0    0    0   0               0             0              0
# 88     0    0    0    0   0               0             0              0
# 89     0    0    0    0   0               0             0              0
# 90     0    0    0    0   1               0             0              0
#
#     surface_Hard
# 86             1
# 87             1
# 88             1
# 89             1
# 90             1

# %%
# We now take the logarithms of P1 nad P2, then create a variable D
df4 = df_2.copy()
df4['winner_rank'] = np.log2(df4['winner_rank'].astype('float64')) 
df4['loser_rank'] = np.log2(df4['loser_rank'].astype('float64')) 
df4['D'] = df4['winner_rank'] - df4['loser_rank']
df4['D'] = np.absolute(df4['D'])
df4.head()
# Out:
#    tourney_date             tourney_name  winner_rank  loser_rank  win  F  QF  \
# 86   2010-11-01  Tournament of Champions     5.727920    3.459432    0  0   1
# 87   2010-11-01  Tournament of Champions     4.584963    4.321928    0  0   1
# 88   2010-11-01  Tournament of Champions     4.954196    4.459432    0  0   1
# 89   2010-11-01  Tournament of Champions     4.754888    4.169925    0  0   1
# 90   2010-11-01  Tournament of Champions     4.584963    5.727920    1  0   0
#
#     R128  R16  R32  R64  SF  surface_Carpet  surface_Clay  surface_Grass  \
# 86     0    0    0    0   0               0             0              0
# 87     0    0    0    0   0               0             0              0
# 88     0    0    0    0   0               0             0              0
# 89     0    0    0    0   0               0             0              0
# 90     0    0    0    0   1               0             0              0
#
#     surface_Hard         D
# 86             1  2.268489
# 87             1  0.263034
# 88             1  0.494765
# 89             1  0.584963
# 90             1  1.142958

# %% [markdown]
# ### Logistic Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
# Logit Function
def logit(x):
    return np.exp(x)  / (1 + np.exp(x)) 
    
x = np.linspace(-6,6,50, dtype=float)

y = logit(x)

plt.plot(x, y)
plt.ylabel("Probability")
plt.show()

# %%
df4.columns.tolist()
# Out:
# ['tourney_date',
#  'tourney_name',
#  'winner_rank',
#  'loser_rank',
#  'win',
#  'F',
#  'QF',
#  'R128',
#  'R16',
#  'R32',
#  'R64',
#  'SF',
#  'surface_Carpet',
#  'surface_Clay',
#  'surface_Grass',
#  'surface_Hard',
#  'D']

# %%
df4.head()
# Out:
#    tourney_date             tourney_name  winner_rank  loser_rank  win  F  QF  \
# 86   2010-11-01  Tournament of Champions     5.727920    3.459432    0  0   1
# 87   2010-11-01  Tournament of Champions     4.584963    4.321928    0  0   1
# 88   2010-11-01  Tournament of Champions     4.954196    4.459432    0  0   1
# 89   2010-11-01  Tournament of Champions     4.754888    4.169925    0  0   1
# 90   2010-11-01  Tournament of Champions     4.584963    5.727920    1  0   0
#
#     R128  R16  R32  R64  SF  surface_Carpet  surface_Clay  surface_Grass  \
# 86     0    0    0    0   0               0             0              0
# 87     0    0    0    0   0               0             0              0
# 88     0    0    0    0   0               0             0              0
# 89     0    0    0    0   0               0             0              0
# 90     0    0    0    0   1               0             0              0
#
#     surface_Hard         D
# 86             1  2.268489
# 87             1  0.263034
# 88             1  0.494765
# 89             1  0.584963
# 90             1  1.142958

# %%
cols_to_keep = ['F', 'QF', 'R128', 'R16', 'R32', 'R64', 'SF', 'D', 'surface_Clay', 'surface_Hard', 'surface_Grass']
# Dropping NaN
X = df4[cols_to_keep].dropna()
X.head()
# Out:
#     F  QF  R128  R16  R32  R64  SF         D  surface_Clay  surface_Hard  \
# 86  0   1     0    0    0    0   0  2.268489             0             1
# 87  0   1     0    0    0    0   0  0.263034             0             1
# 88  0   1     0    0    0    0   0  0.494765             0             1
# 89  0   1     0    0    0    0   0  0.584963             0             1
# 90  0   0     0    0    0    0   1  1.142958             0             1
#
#     surface_Grass
# 86              0
# 87              0
# 88              0
# 89              0
# 90              0

# %%
# Separate the Features (X) from the Target (y)
y = df4["win"]

# %%
# Split our data into training and testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
X_train.shape
# Out:
# (16050, 11)

# %%
# Create a Logistic Regression Model
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs',
                                max_iter=200,
                                random_state=1)

# %%
# Fit (train) or model using the training data
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200, random_state=1)

# %%
# Make predictions
y_pred = classifier.predict(X_test)
results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
results.head(20)
# Out:
#     Prediction  Actual
# 0            1       1
# 1            1       0
# 2            1       0
# 3            1       1
# 4            1       1
# 5            1       1
# 6            1       0
# 7            1       1
# 8            1       1
# 9            1       1
# 10           1       0
# 11           1       1
# 12           1       0
# 13           1       0
# 14           1       1
# 15           1       0
# 16           1       1
# 17           1       1
# 18           1       0
# 19           1       0

# %%
# Print the accuracy
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.635582134180527

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[  62, 1887],
#        [  63, 3339]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.50      0.03      0.98      0.06      0.18      0.03      1949
#           1       0.64      0.98      0.03      0.77      0.18      0.03      3402
#
# avg / total       0.59      0.64      0.38      0.51      0.18      0.03      5351

# %%
# features sorted in descending order by feature importance
brfc = BalancedRandomForestClassifier(random_state=1, n_estimators=100)
brfc.fit(X_train, y_train)
features_importance = brfc.feature_importances_
features = sorted(zip(X.columns, features_importance), reverse=True, key = lambda x: x[1])
features
# Out:
# [('D', 0.9796899448094251),
#  ('surface_Grass', 0.00280489749559638),
#  ('surface_Clay', 0.0027375618298912724),
#  ('surface_Hard', 0.0026311305149040415),
#  ('R128', 0.0024725611618518534),
#  ('R16', 0.0019075927230395985),
#  ('R32', 0.0017935166033697743),
#  ('R64', 0.0017245697985985614),
#  ('F', 0.0014306119993197314),
#  ('SF', 0.0014186933323137297),
#  ('QF', 0.0013889197316898911)]

# %%
from sklearn import metrics

# %%
y_pred_prob = classifier.predict_proba(X_test)[:, 1]
auc_score = metrics.roc_auc_score(y_test, y_pred_prob)
auc_score
# Out:
# 0.5966453801810965

# %%
# Create ROC curve
y_pred_prob = classifier.predict_proba(X_test)[:, 1]
auc_score = metrics.roc_auc_score(y_test, y_pred_prob)
auc_score
fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob)
fig = plt.plot(fpr, tpr,label='ROC curve (area = %0.2f)' % auc_score )
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for win classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.legend(loc="lower right")
plt.grid(True)

# %% [markdown]
# ### Random Forest

# %%
# Resample the training data with the BalancedRandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
brfc = BalancedRandomForestClassifier(random_state=1, n_estimators=100)
brfc.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(random_state=1)

# %%
# Calculated the balanced accuracy score
from sklearn.metrics import balanced_accuracy_score
y_predict = brfc.predict(X_test)
bas = balanced_accuracy_score(y_test, y_predict)
bas
# Out:
# 0.5129364340355732

# %%
# Display the confusion matrix
confusion_matrix(y_test, y_predict)
# Out:
# array([[ 998,  951],
#        [1654, 1748]], dtype=int64)

# %%
# Print the imbalanced classification report
print(classification_report_imbalanced(y_test, y_predict))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.38      0.51      0.51      0.43      0.51      0.26      1949
#           1       0.65      0.51      0.51      0.57      0.51      0.26      3402
#
# avg / total       0.55      0.51      0.51      0.52      0.51      0.26      5351

# %%
# List the features sorted in descending order by feature importance
features_importance = brfc.feature_importances_
features = sorted(zip(X.columns, features_importance), reverse=True, key = lambda x: x[1])
features
# Out:
# [('D', 0.9796899448094251),
#  ('surface_Grass', 0.00280489749559638),
#  ('surface_Clay', 0.0027375618298912724),
#  ('surface_Hard', 0.0026311305149040415),
#  ('R128', 0.0024725611618518534),
#  ('R16', 0.0019075927230395985),
#  ('R32', 0.0017935166033697743),
#  ('R64', 0.0017245697985985614),
#  ('F', 0.0014306119993197314),
#  ('SF', 0.0014186933323137297),
#  ('QF', 0.0013889197316898911)]
